# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('revelleit.db')

# %%
top_5 = pd.read_sql_query("""
    SELECT Marque, Modele, Score_Final, GWP, ADPe, WU, ADPf, TPE, WEEE
    FROM impacts_calcules
    ORDER BY Score_Final DESC
    LIMIT 5
""", conn)

# %%
print("Top 5 des équipements avec le meilleur score")
top_5
# Out:
# Top 5 des équipements avec le meilleur score
#     Marque        Modele  Score_Final     GWP      ADPe     WU    ADPf  \
# 0  Fujitsu  Esprimo Q958          4.7  284.32  0.007756  6.088  1875.2
# 1  Fujitsu  Esprimo Q958          4.7  284.32  0.007756  6.088  1875.2
# 2  Fujitsu  Esprimo Q958          4.7  284.32  0.007756  6.088  1875.2
# 3  Fujitsu  Esprimo Q958          4.7  284.32  0.007756  6.088  1875.2
# 4  Fujitsu  Esprimo Q958          4.7  284.32  0.007756  6.088  1875.2
#
#       TPE    WEEE
# 0  3234.4  8.2928
# 1  3234.4  8.2928
# 2  3234.4  8.2928
# 3  3234.4  8.2928
# 4  3234.4  8.2928
